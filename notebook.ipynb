# %%
import pandas as pd

df = pd.read_csv("data.csv")
print(df.head())
# Out:
#    amount  is_international  hour  device_new  is_fraud
# 0   12000                 0    14           0         0
# 1  450000                 1    23           1         1
# 2   80000                 0    10           0         0
# 3  320000                 1    22           0         1
# 4   15000                 0     3           1         1
